# %% [markdown]
# #Import Library

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# #Read CSV

# %%
df = pd.read_csv('/content/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# 1. Mencari Missing Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Tidak ditemukan missing value

# %% [markdown]
# ----

# %% [markdown]
# 2. Mencari duplicate value

# %%
df[df.duplicated()]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# 31        2   0     2       1
# 43        2   0     3       0
# 55        0   0     3       0
# 61        1   1     2       1
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [723 rows x 14 columns]

# %% [markdown]
# ditemukan 723 duplicate value

# %% [markdown]
# -----

# %% [markdown]
# - Handling duplicate value

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %% [markdown]
# Setelah di handling dengan cara didrop didapatkan data unik sejumlah 302 baris

# %% [markdown]
# 3. Mencari outlier

# %% [markdown]
# - Menggunakan Box Plot

# %%
fig, ax = plt.subplots()

custom_bins = [25, 35, 45, 55, 65, 75, 90]
_ = ax.hist('age', bins=custom_bins, data=df)
_ = ax.set(xlabel='Umur', ylabel='Jumlah')

_ = ax.set_xticks(custom_bins)

# %% [markdown]
# Dari hasil boxplot didapatkan distribusi umur paling banyak berada di umur 45 - 65 tahun.

# %%
fig, ax = plt.subplots()

custom_bins = [0, 120, 130, 140, 180,200]
_ = ax.hist('trestbps', bins=custom_bins, data=df,
                            facecolor='blue', edgecolor='white')
_ = ax.set_xticks(custom_bins)
_ = ax.set_ylabel('jumlah')
_ = ax.set_xlabel('tekanan darah')

# %% [markdown]
# Boxplot tersebut mendapatkan hasil bahwa kebanyakan pasien mengidap prahipertensi (120-129), hipertensi derajat 1 (130-139) sampai dengan hipertensi derajat 2 (140-180) dengan sebagian kecil mengidap krisis hipertensi.
#
# https://www.alodokter.com/seperti-ini-cara-membaca-hasil-pemeriksaan-tekanan-darah

# %%
fig, ax = plt.subplots()

_ = ax.hist('chol', bins='auto', data=df)
_ = ax.set_ylabel('jumlah')
_ = ax.set_xlabel('kolestrol')

# %% [markdown]
# Terdapat distribusi tidak normal di rentang lebih dari 380

# %% [markdown]
# * Handling Outlier

# %%
def outmed(chol, threshold=380):
    # Hitung median
    median = np.median(chol)

    # Ganti outlier dengan median
    if chol < threshold:
      return median

# %%
df ['chol'] = df['chol'].apply(outmed)

# %%
fig, ax = plt.subplots()

_ = ax.hist('chol', bins='auto', data=df)
_ = ax.set_ylabel('jumlah')
_ = ax.set_xlabel('kolestrol')

# %% [markdown]
# Setelah handling outliers, distribusi menjadi normal.

# %%
fig, ax = plt.subplots()

_ = ax.hist('thalach', bins='auto', data=df)
_ = ax.set_ylabel('jumlah')
_ = ax.set_xlabel('')

# %%
fig, ax = plt.subplots()

_ = ax.hist('oldpeak', bins='auto', data=df)
_ = ax.set_ylabel('jumlah')
_ = ax.set_xlabel('')

# %% [markdown]
# Data di rentang 0-1 menmiliki kuantitas paling banyak.

# %% [markdown]
# * Menggunakan Pie Chart

# %%
df['sex'] = df['sex'].astype('category')
df['cp'] = df['cp'].astype('category')
df['fbs'] = df['fbs'].astype('category')
df['restecg'] = df['restecg'].astype('category')
df['exang'] = df['exang'].astype('category')
df['target'] = df['target'].astype('category')

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='sex'>

# %% [markdown]
# Data usia menunjukkan distribusi yang berpusat di umur 45 - 65 tahun

# %%
df['cp'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='cp'>

# %% [markdown]
# Pasien paling banyak mengalami Atypical Angina dan Typical Angina

# %%
df['fbs'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='fbs'>

# %% [markdown]
# Hanya sebagian kecil pasien yang fasting blood sugarnya lebih dari 120 mg/dl.

# %%
df['restecg'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='restecg'>

# %% [markdown]
# 50% pasien berstatus normal dengan sebagian besar mengalami hipertropi dan sebagian kecil mengalami ST-T

# %%
df['exang'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='exang'>

# %% [markdown]
#  # Feature Jenis Kelamin

# %%
def jkel (sex):
    if sex == 0:
        return 'Female'
    if sex == 1:
        return 'Male'

# %%
df['Jenis_Kelamin'] = df['sex'].apply(jkel)
df.head()
# Out:
#    age sex cp  trestbps   chol fbs restecg  thalach exang  oldpeak  slope  ca  \
# 0   52   1  0       125  212.0   0       1      168     0      1.0      2   2
# 1   53   1  0       140  203.0   1       0      155     1      3.1      0   0
# 2   70   1  0       145  174.0   0       1      125     1      2.6      0   0
# 3   61   1  0       148  203.0   0       1      161     0      0.0      2   1
# 4   62   0  0       138  294.0   1       1      106     0      1.9      1   3
#
#    thal target Jenis_Kelamin
# 0     3      0          Male
# 1     3      0          Male
# 2     3      0          Male
# 3     3      0          Male
# 4     2      0        Female

# %% [markdown]
# # Feature Kelompok Usia
# * 0 - 44 = Muda
# * 45 - 60 = Paruh Baya
# * 60 - 90 = Tua

# %%
def klus (age):
    if 0 <= age <= 44:
        return 'Muda'
    elif 45 <= age <= 60:
        return 'Paruh Baya'
    else:
        return 'Tua'

# %%
df['Kelompok Usia'] = df['age'].apply(klus)
df
# Out:
#      age sex cp  trestbps   chol fbs restecg  thalach exang  oldpeak  slope  \
# 0     52   1  0       125  212.0   0       1      168     0      1.0      2
# 1     53   1  0       140  203.0   1       0      155     1      3.1      0
# 2     70   1  0       145  174.0   0       1      125     1      2.6      0
# 3     61   1  0       148  203.0   0       1      161     0      0.0      2
# 4     62   0  0       138  294.0   1       1      106     0      1.9      1
# ..   ...  .. ..       ...    ...  ..     ...      ...   ...      ...    ...
# 723   68   0  2       120  211.0   0       0      115     0      1.5      1
# 733   44   0  2       108  141.0   0       1      175     0      0.6      1
# 739   52   1  0       128  255.0   0       1      161     1      0.0      2
# 843   59   1  3       160  273.0   0       0      125     0      0.0      2
# 878   54   1  0       120  188.0   0       1      113     0      1.4      1
#
#      ca  thal target Jenis_Kelamin Kelompok Usia
# 0     2     3      0          Male    Paruh Baya
# 1     0     3      0          Male    Paruh Baya
# 2     0     3      0          Male           Tua
# 3     1     3      0          Male           Tua
# 4     3     2      0        Female           Tua
# ..   ..   ...    ...           ...           ...
# 723   0     2      1        Female           Tua
# 733   0     2      1        Female          Muda
# 739   1     3      0          Male    Paruh Baya
# 843   0     2      0          Male    Paruh Baya
# 878   1     3      0          Male    Paruh Baya
#
# [302 rows x 16 columns]

# %% [markdown]
# # Feature Chest Pain
# * 1 = atypical angina
# * 2 = typical angina
# * 3 = asymptomatic
# * 4 = nonanginal pain

# %%
def cpt (cp):
    if cp == 1:
        return ' atypical angina'
    elif cp == 2:
        return 'typical angina'
    elif cp == 3:
        return 'asymptomatic'
    else:
        return 'nonanginal pain'

# %%
df['Chest Pain'] =df['cp'].apply(cpt)
df
# Out:
#      age sex cp  trestbps   chol fbs restecg  thalach exang  oldpeak  slope  \
# 0     52   1  0       125  212.0   0       1      168     0      1.0      2
# 1     53   1  0       140  203.0   1       0      155     1      3.1      0
# 2     70   1  0       145  174.0   0       1      125     1      2.6      0
# 3     61   1  0       148  203.0   0       1      161     0      0.0      2
# 4     62   0  0       138  294.0   1       1      106     0      1.9      1
# ..   ...  .. ..       ...    ...  ..     ...      ...   ...      ...    ...
# 723   68   0  2       120  211.0   0       0      115     0      1.5      1
# 733   44   0  2       108  141.0   0       1      175     0      0.6      1
# 739   52   1  0       128  255.0   0       1      161     1      0.0      2
# 843   59   1  3       160  273.0   0       0      125     0      0.0      2
# 878   54   1  0       120  188.0   0       1      113     0      1.4      1
#
#      ca  thal target Jenis_Kelamin Kelompok Usia       Chest Pain
# 0     2     3      0          Male    Paruh Baya  nonanginal pain
# 1     0     3      0          Male    Paruh Baya  nonanginal pain
# 2     0     3      0          Male           Tua  nonanginal pain
# 3     1     3      0          Male           Tua  nonanginal pain
# 4     3     2      0        Female           Tua  nonanginal pain
# ..   ..   ...    ...           ...           ...              ...
# 723   0     2      1        Female           Tua   typical angina
# 733   0     2      1        Female          Muda   typical angina
# 739   1     3      0          Male    Paruh Baya  nonanginal pain
# 843   0     2      0          Male    Paruh Baya     asymptomatic
# 878   1     3      0          Male    Paruh Baya  nonanginal pain
#
# [302 rows x 17 columns]

# %% [markdown]
# #Fitur Hipertensi

# %%
def tek (td):
    if 0 < td <= 120 :
        return 'Normal'
    elif 121 <= td <= 130 :
        return 'Prahipertensi'
    elif  130 < td <= 139:
        return 'Hipertensi 1'
    elif 140 < td  <= 180:
        return 'Hipertensi 2'
    else:
        return 'Krisis'

# %%
df['Hipertensi'] =df['trestbps'].apply(tek)
df
# Out:
#      age sex cp  trestbps   chol fbs restecg  thalach exang  oldpeak  slope  \
# 0     52   1  0       125  212.0   0       1      168     0      1.0      2
# 1     53   1  0       140  203.0   1       0      155     1      3.1      0
# 2     70   1  0       145  174.0   0       1      125     1      2.6      0
# 3     61   1  0       148  203.0   0       1      161     0      0.0      2
# 4     62   0  0       138  294.0   1       1      106     0      1.9      1
# ..   ...  .. ..       ...    ...  ..     ...      ...   ...      ...    ...
# 723   68   0  2       120  211.0   0       0      115     0      1.5      1
# 733   44   0  2       108  141.0   0       1      175     0      0.6      1
# 739   52   1  0       128  255.0   0       1      161     1      0.0      2
# 843   59   1  3       160  273.0   0       0      125     0      0.0      2
# 878   54   1  0       120  188.0   0       1      113     0      1.4      1
#
#      ca  thal target Jenis_Kelamin Kelompok Usia       Chest Pain  \
# 0     2     3      0          Male    Paruh Baya  nonanginal pain
# 1     0     3      0          Male    Paruh Baya  nonanginal pain
# 2     0     3      0          Male           Tua  nonanginal pain
# 3     1     3      0          Male           Tua  nonanginal pain
# 4     3     2      0        Female           Tua  nonanginal pain
# ..   ..   ...    ...           ...           ...              ...
# 723   0     2      1        Female           Tua   typical angina
# 733   0     2      1        Female          Muda   typical angina
# 739   1     3      0          Male    Paruh Baya  nonanginal pain
# 843   0     2      0          Male    Paruh Baya     asymptomatic
# 878   1     3      0          Male    Paruh Baya  nonanginal pain
#
#         Hipertensi Tingkat Kolestrol
# 0    Prahipertensi             Batas
# 1           Krisis             Batas
# 2     Hipertensi 2            Normal
# 3     Hipertensi 2             Batas
# 4     Hipertensi 1            Tinggi
# ..             ...               ...
# 723         Normal             Batas
# 733         Normal            Normal
# 739  Prahipertensi            Tinggi
# 843   Hipertensi 2            Tinggi
# 878         Normal            Normal
#
# [302 rows x 19 columns]

# %% [markdown]
# # Fitur kolestrol

# %%
def col (chol):
    if 0 < chol <= 200 :
        return 'Normal'
    elif 201 <= chol <= 239 :
        return 'Batas'
    else:
        return 'Tinggi'

# %%
df['Tingkat Kolestrol'] =df['chol'].apply(col)
df
# Out:
#      age sex cp  trestbps   chol fbs restecg  thalach exang  oldpeak  slope  \
# 0     52   1  0       125  212.0   0       1      168     0      1.0      2
# 1     53   1  0       140  203.0   1       0      155     1      3.1      0
# 2     70   1  0       145  174.0   0       1      125     1      2.6      0
# 3     61   1  0       148  203.0   0       1      161     0      0.0      2
# 4     62   0  0       138  294.0   1       1      106     0      1.9      1
# ..   ...  .. ..       ...    ...  ..     ...      ...   ...      ...    ...
# 723   68   0  2       120  211.0   0       0      115     0      1.5      1
# 733   44   0  2       108  141.0   0       1      175     0      0.6      1
# 739   52   1  0       128  255.0   0       1      161     1      0.0      2
# 843   59   1  3       160  273.0   0       0      125     0      0.0      2
# 878   54   1  0       120  188.0   0       1      113     0      1.4      1
#
#      ca  thal target Jenis_Kelamin Kelompok Usia       Chest Pain  \
# 0     2     3      0          Male    Paruh Baya  nonanginal pain
# 1     0     3      0          Male    Paruh Baya  nonanginal pain
# 2     0     3      0          Male           Tua  nonanginal pain
# 3     1     3      0          Male           Tua  nonanginal pain
# 4     3     2      0        Female           Tua  nonanginal pain
# ..   ..   ...    ...           ...           ...              ...
# 723   0     2      1        Female           Tua   typical angina
# 733   0     2      1        Female          Muda   typical angina
# 739   1     3      0          Male    Paruh Baya  nonanginal pain
# 843   0     2      0          Male    Paruh Baya     asymptomatic
# 878   1     3      0          Male    Paruh Baya  nonanginal pain
#
#         Hipertensi Tingkat Kolestrol
# 0    Prahipertensi             Batas
# 1           Krisis             Batas
# 2     Hipertensi 2            Normal
# 3     Hipertensi 2             Batas
# 4     Hipertensi 1            Tinggi
# ..             ...               ...
# 723         Normal             Batas
# 733         Normal            Normal
# 739  Prahipertensi            Tinggi
# 843   Hipertensi 2            Tinggi
# 878         Normal            Normal
#
# [302 rows x 19 columns]

# %% [markdown]
# Boxplot tersebut mendapatkan hasil bahwa kebanyakan pasien mengidap prahipertensi (120-129), hipertensi derajat 1 (130-139) sampai dengan hipertensi derajat 2 (140-180) dengan sebagian kecil mengidap krisis hipertensi.
